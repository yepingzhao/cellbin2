# %%
import scanpy as sc
import stereo as st
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ### _Transcriptomics.cellbin.gef

# %%
cell_data_path = "test/Y40178MC/Y40178MC_Transcriptomics.cellbin.gef"
cell_data = st.io.read_gef(file_path=cell_data_path, bin_type='cell_bins')
# cell_data.tl.cal_qc()
# Out:
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1339][INFO]: read_gef begin ...
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1554][INFO]: This is GEF file which contains cell bin infomation.
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1555][INFO]: bin_type: cell_bins
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1561][INFO]: Number of cells: 11648
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1564][INFO]: Number of gene: 51817
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1567][INFO]: Resolution: 500
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1570][INFO]: offsetX: 0
# [2026-04-09 13:09:59][Stereo][1021802][MainThread][139884910159680][reader][1573][INFO]: offsetY: 0
# ...

# %%
print(cell_data)
# print(cell_data.cells_matrix["cell_border"])
# Out:
# StereoExpData object with n_cells X n_genes = 11648 X 51817
# bin_type: cell_bins
# offset_x = None
# offset_y = None
# cells: ['cell_name', 'dnbCount', 'area']
# genes: ['gene_name', 'real_gene_name']
# cells_matrix = ['cell_border', 'spatial']
# Layers with keys:
# tl.result: []

# %%
# cell_data.plt.spatial_scatter()

# %%
cell_data_path = "test/Y40178P5/Y40178P5_Transcriptomics.cellbin.gef"
cell_data = st.io.read_gef(file_path=cell_data_path, bin_type='cell_bins')
# cell_data.tl.cal_qc()

print(cell_data)

# cell_data.plt.spatial_scatter()
# Out:
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1339][INFO]: read_gef begin ...
# 2026-04-09 13:09:56 [INFO   ] version is 1.2.5
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1554][INFO]: This is GEF file which contains cell bin infomation.
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1555][INFO]: bin_type: cell_bins
# 2026-04-09 13:09:56 [INFO   ] version is 1.2.5
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1561][INFO]: Number of cells: 10844
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1564][INFO]: Number of gene: 52026
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1567][INFO]: Resolution: 500
# [2026-04-09 13:09:56][Stereo][1021802][MainThread][139884910159680][reader][1570][INFO]: offsetX: 0
# ...

# %% [markdown]
# ### Merge.gef

# %%
cell_data_path = "test/merged.cellbin.gef"
cell_data = st.io.read_gef(file_path=cell_data_path, bin_type='cell_bins')
cell_data.tl.cal_qc()

print(cell_data)

cell_data.plt.spatial_scatter()
# Out:
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1339][INFO]: read_gef begin ...
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1554][INFO]: This is GEF file which contains cell bin infomation.
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1555][INFO]: bin_type: cell_bins
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1561][INFO]: Number of cells: 22194
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1564][INFO]: Number of gene: 14
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1567][INFO]: Resolution: 500
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1570][INFO]: offsetX: 0
# [2026-04-08 16:13:28][Stereo][1831645][MainThread][140553892710208][reader][1573][INFO]: offsetY: 0
# ...
