# %%
import scanpy as sc

h5ad_file_path = "data/Y40178MC/Y40178MC.h5ad"
h5ad_data = sc.read_h5ad(h5ad_file_path)
h5ad_data
# Out:
# AnnData object with n_obs × n_vars = 10187 × 29820
#     obsm: 'spatial'

# %%
import stereo as st

file_path = "test/Y40178MC/Y40178MC_Transcriptomics.cellbin.gef"
data = st.io.read_gef(file_path, bin_type='cell_bins')
data
# Out:
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1339][INFO]: read_gef begin ...
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1554][INFO]: This is GEF file which contains cell bin infomation.
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1555][INFO]: bin_type: cell_bins
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1561][INFO]: Number of cells: 11648
# 2026-04-05 21:31:25 [INFO   ] version is 1.2.5
# 2026-04-05 21:31:25 [INFO   ] version is 1.2.5
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1564][INFO]: Number of gene: 51817
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1567][INFO]: Resolution: 500
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1570][INFO]: offsetX: 0
# [2026-04-05 21:31:25][Stereo][233367][MainThread][140669457258304][reader][1573][INFO]: offsetY: 0
# ...

# %%
adjusted_file_path = "test/Y40178MC/Y40178MC_Transcriptomics.adjusted.cellbin.gef"
adjusted_data = st.io.read_gef(adjusted_file_path, bin_type='cell_bins')
adjusted_data
# Out:
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1339][INFO]: read_gef begin ...
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1554][INFO]: This is GEF file which contains cell bin infomation.
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1555][INFO]: bin_type: cell_bins
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1561][INFO]: Number of cells: 11729
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1564][INFO]: Number of gene: 51817
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1567][INFO]: Resolution: 500
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1570][INFO]: offsetX: 0
# [2026-04-05 21:31:45][Stereo][233367][MainThread][140669457258304][reader][1573][INFO]: offsetY: 0
# ...
